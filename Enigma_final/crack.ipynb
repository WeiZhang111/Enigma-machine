# %%
from single_elements import *  
from rotor import *
from enigma import *

# %%
# necessary lists for the purpose of loop:
reflectors = [REFLECTOR_A,REFLECTOR_B,REFLECTOR_C]
ALPHABET = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %% [markdown]
# Code 1

# %%
# find the correct reflector
j = 1
for i in reflectors:
    E1 = Enigma(i, ROTOR_Beta, ROTOR_Gamma, ROTOR_V, 'MJM', plugs='KI XN FL',ring="DBN")
    
    print('reflector #',j,'results: ',E1.encipher('DMEXBMKYCVPNQBEDHXVPZGKMTFFBJRPJTLHLCHOTKOYXGGHZ'))
    j += 1
# Out:
# reflector # 1 results:  SBTBKYOJEJIYJSLLODFBMMFKKNNOZPICXJLNFUPBZEKZTZES
# reflector # 2 results:  CVJGVZNANRYBCQWBQZIQRFCUAJVJLTOERWVKNCQNGPPISHWR
# reflector # 3 results:  NICEWORKYOUVEMANAGEDTODECODETHEFIRSTSECRETSTRING

# %% [markdown]
# Code 2

# %%
# find the correct starting positions
for i in ALPHABET:
    for j in ALPHABET:
        for k in ALPHABET:
            starting = i+j+k
            E1 = Enigma(REFLECTOR_B, ROTOR_Beta, ROTOR_I, ROTOR_III, starting, plugs='VH PT ZG BJ EY FS',ring="WBJ")
            rst = E1.encipher('CMFSUPKNCBMUYEQVVDYKLRQZTPUFHSWWAKTUGXMPAMYAFITXIJKMH')
            if 'UNIVERSITY' in rst:
                print(starting,' results:')
                print(rst)
# Out:
# IMG  results:
# IHOPEYOUAREENJOYINGTHEUNIVERSITYOFBATHEXPERIENCESOFAR

# %% [markdown]
# Code 3

# %%
# Preferable rings:
prefer_rings = []
for i in [2,4,6,8,20,22,24,26]:
    prefer_rings.append(chr(ord('A')+i-1))
prefer_rings
# Out:
# ['B', 'D', 'F', 'H', 'T', 'V', 'X', 'Z']

# %%
# put all possible rings in a list
rings_list = []
for i in prefer_rings:
    for j in prefer_rings:
        for k in prefer_rings:
            rst = i+j+k
            rings_list.append(rst)
# rings_list

# %%
even_rotors = [ROTOR_II, ROTOR_IV]
for j in reflectors:
    for k in rings_list:
        E1 = Enigma(j, ROTOR_II, ROTOR_II, ROTOR_II, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E1.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_II, ROTOR_II, ROTOR_II:','reflector ',j, 'rings: ',k)
            print(rst)
        E2 = Enigma(j, ROTOR_II,ROTOR_II, ROTOR_IV, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E2.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_II,ROTOR_II, ROTOR_IV:','reflector ',j, 'rings: ',k)
            print(rst)
        E3 = Enigma(j, ROTOR_II, ROTOR_IV, ROTOR_II, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E3.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_II, ROTOR_IV, ROTOR_II:','reflector ',j, 'rings: ',k)
            print(rst)
        E4 = Enigma(j, ROTOR_II, ROTOR_IV, ROTOR_IV, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E4.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_II, ROTOR_IV, ROTOR_IV:','reflector ',j, 'rings: ',k)
            print(rst)
        E5 = Enigma(j, ROTOR_IV, ROTOR_II, ROTOR_II, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E5.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_IV, ROTOR_II, ROTOR_II:','reflector ',j, 'rings: ',k)
            print(rst)
        E6 = Enigma(j, ROTOR_IV, ROTOR_II, ROTOR_IV, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E6.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('OTOR_IV, ROTOR_II, ROTOR_IV:','reflector ',j, 'rings: ',k)
            print(rst)
        E7 = Enigma(j, ROTOR_IV, ROTOR_IV, ROTOR_II, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E7.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_IV, ROTOR_IV, ROTOR_II:','reflector ',j, 'rings: ',k)
            print(rst)
        E8 = Enigma(j, ROTOR_IV, ROTOR_IV, ROTOR_IV, 'EMY', plugs='FH TS BE UQ KD AL',ring=k)
        rst = E8.encipher('ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY')
        if 'THOUSAND' in rst:
            print('ROTOR_IV, ROTOR_IV, ROTOR_IV:','reflector ',j, 'rings: ',k)
            print(rst)

# %% [markdown]
# Code 4

# %%
# WP RJ A? VF I? HN CG BS

# compose all possible plugs into a list
plugs_list = []
for i in ALPHABET:
    for j in ALPHABET:
        rst = 'WP RJ A'+i+' VF I'+j+' HN CG BS'
        plugs_list.append(rst)
plugs_list
# Out:
# ['WP RJ AA VF IA HN CG BS',
#  'WP RJ AA VF IB HN CG BS',
#  'WP RJ AA VF IC HN CG BS',
#  'WP RJ AA VF ID HN CG BS',
#  'WP RJ AA VF IE HN CG BS',
#  'WP RJ AA VF IF HN CG BS',
#  'WP RJ AA VF IG HN CG BS',
#  'WP RJ AA VF IH HN CG BS',
#  'WP RJ AA VF II HN CG BS',
#  'WP RJ AA VF IJ HN CG BS',
#  'WP RJ AA VF IK HN CG BS',
#  'WP RJ AA VF IL HN CG BS',
#  'WP RJ AA VF IM HN CG BS',
#  'WP RJ AA VF IN HN CG BS',
#  'WP RJ AA VF IO HN CG BS',
#  'WP RJ AA VF IP HN CG BS',
#  'WP RJ AA VF IQ HN CG BS',
#  'WP RJ AA VF IR HN CG BS',
#  'WP RJ AA VF IS HN CG BS',
#  'WP RJ AA VF IT HN CG BS',
#  'WP RJ AA VF IU HN CG BS',
#  'WP RJ AA VF IV HN CG BS',
#  'WP RJ AA VF IW HN CG BS',
#  'WP RJ AA VF IX HN CG BS',
#  'WP RJ AA VF IY HN CG BS',
#  'WP RJ AA VF IZ HN CG BS',
#  'WP RJ AB VF IA HN CG BS',
#  'WP RJ AB VF IB HN CG BS',
#  'WP RJ AB VF IC HN CG BS',
#  'WP RJ AB VF ID HN CG BS',
#  'WP RJ AB VF IE HN CG BS',
#  'WP RJ AB VF IF HN CG BS',
#  'WP RJ AB VF IG HN CG BS',
# ...

# %%
for i in plugs_list:
    E1 = Enigma(REFLECTOR_A, ROTOR_V, ROTOR_III, ROTOR_IV, 'SWU', plugs=i,ring="XLJ")
    rst = E1.encipher('SDNTVTPHRBNWTLMZTQKZGADDQYPFNHBPNHCQGBGMZPZLUAVGDQVYRBFYYEIXQWVTHXGNW')
    if 'TUTOR' in rst:
        print(i)
        print(rst)
# Out:
# WP RJ AT VF IB HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCATEDOFCRKMESDURKNGTHEMABKNGOFTHWSEEXAMPLES
# WP RJ AT VF IC HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCATEDOFCRKMESDURKNGTHEMACKNGOFTHPSEEXAMPLES
# WP RJ AT VF ID HN CG BS
# NHTUTORSWEREHARMEIEORKZSLKCATEIOFCRKMESIURKNGTHEZADKNGOFTHXSEEXAMPLES
# WP RJ AT VF IE HN CG BS
# NOTUTORSWIRIHARMIDIORKMPLKCATIDOFCRKMISDURKNGTHIMAEKNGOFTZKSIIXAMPLIS
# WP RJ AT VF IF HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCQTEDOFCRKMESDURKNGTHEMAFKNGKFTHOSEEXAMPLES
# WP RJ AT VF IG HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCATEDOFCRKMESDURKNGTHEMAGKNGOFTHLSEEXAMPLES
# WP RJ AT VF IH HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCATEDOFCRKMESDURKNGTHEMAHKNGOFTHTSEEXAMPLES
# WP RJ AT VF II HN CG BS
# NOTUTORSWEREHARMEDEORKMPLKCATEDOFCRKMESDURKNGTHEMAIKNGOFTHJSEEXAMPLES
# WP RJ AT VF IK HN CG BS
# NOTUTORSWEREHARMEDNORIMPLICATEDOFCRIMESDURINGTHEMAKINGOFTHESEEXAMPLES
# WP RJ AT VF IL HN CG BS
# NOTUTORSWEREHERMEDEORKMPIKCATEDOFCRKMESDURKTGTHEMALKNGOFTHCSEEXAMPIES
# ...
